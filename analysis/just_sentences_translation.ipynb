# %%
import json

path = r"C:\Users\ingri\Documents\IMIM\experiments\RJH006_subj_obj\transcription_english_NEW.json"
data = json.load(open(path, encoding="utf-8"))

new_data = []
for dic in data["segments"]:
    text_chin = dic["text"]
    text_eng = dic["text_eng"]
    print(text_chin)
    print(text_eng)
    new_data.append({"text_chin": text_chin, "text_eng": text_eng})

json.dump(new_data, open(r"C:\Users\ingri\Documents\IMIM\experiments\RJH006_subj_obj\RJH006_subj_obj_sentences_translation.json", "w", encoding="utf-8"), ensure_ascii=False, indent=4)
# Out:
# 开始了。首先我是不会说名字啊！
# here we go. First of all, I can’t say the name!
# 嗯。
# Um.
# 朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。
# Zhu Yin, Jiao Enjun, Stephen Chow, Jin Yingjuan, Zhang Yining, Seventy.
# 啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。
# Ah, six seven six four six three, Zhu Yin, Jiao Enjun, Jin Yingjuan, Stephen Chow, Zhang Yining.
# 好，我们下一个计算。接下来是个句子，朱茵教周星驰跳舞，八十二。
# Okay, let's do the next calculation. Next is a sentence, Zhu Yin taught Zhou Xingchi to dance, eighty-two.
# 啊，七十九、七十六，再然后七十三，朱茵教周星驰跳舞。
# Ah, seventy-nine, seventy-six, and then seventy-three, Zhu Yin taught Stephen Chow how to dance.
# 好的，接下来金映娟告诉焦恩俊了一个可怕的秘密，八十二。
# Okay, next Jin Yingjuan told Jiao Enjun a terrible secret, eighty-two.
# 嗯，七九七六七三，金映娟告诉了焦恩俊一个可怕的秘密。
# Well, 797673, Jin Yingjuan told Jiao Enjun a terrible secret.
# 好，继续。张怡宁给朱茵泡茶，二十四。
# OK, continue. Zhang Yining makes tea for Zhu Yin, twenty-four.
# 啊，二一十八、十五，张怡宁给朱茵泡茶。
# Ah, 218, 15, Zhang Yining made tea for Zhu Yin.
# 周星驰邀请金映娟一起去听演唱会，五十九。
# ...

# %%
figs = {k: None for k in keys}

figs["speech_list"]["responsive"] = df_speech_list
figs["speech_subject"]["responsive"] = df_speech_subject
figs["speech_object"]["responsive"] = df_speech_object
figs["listening_list"]["responsive"] = df_listening_list
figs["listening_subject"]["responsive"] = df_listening_subject
figs["listening_object"]["responsive"] = df_listening_object
# Out:
# ['Jin Yingjuan', 'Zhang Yining', 'Jiao Enjun', 'Zhu Yin', 'Stephen Chow']
