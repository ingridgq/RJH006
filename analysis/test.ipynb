# %%
import json
import re
import os 
import pandas as pd

#Paths
#folder_base = r"C:\Users\ingri\Documents\IMIM\experiments\RJH006_subj_obj"
#experiment_name = "RJH006_subj_obj"
#json_path = f"{folder_base}/{experiment_name}_transcription.json"
csv_path = r"C:\Users\ingri\Documents\IMIM\experiments\RJH006_subj_obj\RJH006_subj_obj_names_timestamps_CSV_NEW.csv"
df = pd.read_csv(csv_path)

#Names to find
names = [
    {"name_chin": "朱茵", "name_eng": "Zhu Yin"},
    {"name_chin": "焦恩俊", "name_eng": "Jiao Enjun"},
    {"name_chin": "周星驰", "name_eng": "Stephen Chow"},
    {"name_chin": "金映娟", "name_eng": "Jin Yingjuan"},
    {"name_chin": "张怡宁", "name_eng": "Zhang Yining"},
]

#names_chin = []
ids_names = []

#loop through unique sentences
for sentence in df["chinese_sentence"].unique():
    sentence_dicts = []
    total_count = 0

    #verifying names in sentence
    for name in names:
        n = name["name_chin"]
        if n in sentence:
            id_name = sentence.find(n)
            sentence_dicts.append({
                "sentence": sentence,
                "name": n,
                "id_name": id_name
            })
            total_count += sentence.count(n)
    
    #sentence type classification
    type_sentence = "list_names" if total_count > 2 else "real_sentence"

    #updating sentence dicts (type)
    for dic in sentence_dicts: 
        dic["type_sentence"] = type_sentence

    #list_ids = [ids["id_name"] for ids in ids_names]

        #classification subject/object
        if type_sentence == "real_sentence" and len(sentence_dicts) == 2: 
            n1, n2 = sentence_dicts
            if n1["id_name"] < n2["id_name"]: 
                n1["class_word"], n2["class_word"] = "subject", "object"
            else:
                n1["class_word"], n2["class_word"] = "object", "subject"

        else:
            for dic in sentence_dicts:
                dic["class_word"] = "none"

    #updating main ids_names dicts
    ids_names.extend(sentence_dicts)

#creating temporary auxiliary dataframe
ids_df = pd.DataFrame(ids_names)

#merging dataframes
new_df = df.merge(ids_df, how="left", left_on=["chinese_sentence", "chinese_name"], right_on=["sentence", "name"])

#dropping unnecessary columns
new_df = new_df.drop(columns=["sentence", "name", "id_name", "Unnamed: 0"])

print(new_df.head(20))

#saving to csv and xlsx
output_csv_path = r"C:\Users\ingri\Documents\IMIM\experiments\RJH006_subj_obj"
output_csv_file = "RJH006_subj_obj_names_timestamps_CLASSIFIED_CSV.csv"
output_xlsx_file = "RJH006_subj_obj_names_timestamps_CLASSIFIED_XLSX.xlsx"

new_df.to_csv(f"{output_csv_path}/{output_csv_file}", index=False)
new_df.to_excel(f"{output_csv_path}/{output_xlsx_file}", index=False)
# Out:
#    chinese_name  english_name  start_time  end_time  \
# 0            朱茵       Zhu Yin        6.30      6.66
# 1           焦恩俊    Jiao Enjun        8.16      8.76
# 2           周星驰  Stephen Chow       10.86     11.72
# 3           金映娟  Jin Yingjuan       13.44     14.10
# 4           张怡宁  Zhang Yining       15.96     16.70
# 5            朱茵       Zhu Yin       24.04     24.64
# 6           焦恩俊    Jiao Enjun       25.10     25.74
# 7           周星驰  Stephen Chow       27.30     27.96
# 8           金映娟  Jin Yingjuan       26.40     27.10
# 9           张怡宁  Zhang Yining       28.14     28.66
# 10           朱茵       Zhu Yin       35.44     36.26
# 11          周星驰  Stephen Chow       36.76     38.14
# 12           朱茵       Zhu Yin       46.78     47.28
# 13          周星驰  Stephen Chow       47.50     48.18
# 14          焦恩俊    Jiao Enjun       53.44     54.08
# 15          金映娟  Jin Yingjuan       51.94     52.78
# 16          焦恩俊    Jiao Enjun       61.40     61.82
# 17          金映娟  Jin Yingjuan       59.84     60.36
# 18           朱茵       Zhu Yin       68.70     69.28
# 19          张怡宁  Zhang Yining       67.44     68.40
#
#                    chinese_sentence  \
# 0            朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。
# 1            朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。
# 2            朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。
# 3            朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。
# 4            朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。
# 5      啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。
# 6      啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。
# 7      啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。
# 8      啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。
# 9      啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。
# 10  好，我们下一个计算。接下来是个句子，朱茵教周星驰跳舞，八十二。
# 11  好，我们下一个计算。接下来是个句子，朱茵教周星驰跳舞，八十二。
# 12       啊，七十九、七十六，再然后七十三，朱茵教周星驰跳舞。
# 13       啊，七十九、七十六，再然后七十三，朱茵教周星驰跳舞。
# 14      好的，接下来金映娟告诉焦恩俊了一个可怕的秘密，八十二。
# 15      好的，接下来金映娟告诉焦恩俊了一个可怕的秘密，八十二。
# 16       嗯，七九七六七三，金映娟告诉了焦恩俊一个可怕的秘密。
# 17       嗯，七九七六七三，金映娟告诉了焦恩俊一个可怕的秘密。
# 18               好，继续。张怡宁给朱茵泡茶，二十四。
# 19               好，继续。张怡宁给朱茵泡茶，二十四。
#
#                                      english_sentence  sentence_start  \
# 0   Zhu Yin, Jiao Enjun, Stephen Chow, Jin Yingjua...            6.30
# 1   Zhu Yin, Jiao Enjun, Stephen Chow, Jin Yingjua...            6.30
# 2   Zhu Yin, Jiao Enjun, Stephen Chow, Jin Yingjua...            6.30
# 3   Zhu Yin, Jiao Enjun, Stephen Chow, Jin Yingjua...            6.30
# 4   Zhu Yin, Jiao Enjun, Stephen Chow, Jin Yingjua...            6.30
# 5   Ah, six seven six four six three, Zhu Yin, Jia...           19.72
# 6   Ah, six seven six four six three, Zhu Yin, Jia...           19.72
# 7   Ah, six seven six four six three, Zhu Yin, Jia...           19.72
# 8   Ah, six seven six four six three, Zhu Yin, Jia...           19.72
# 9   Ah, six seven six four six three, Zhu Yin, Jia...           19.72
# 10  Okay, let's do the next calculation. Next is a...           30.56
# 11  Okay, let's do the next calculation. Next is a...           30.56
# 12  Ah, seventy-nine, seventy-six, and then sevent...           40.82
# 13  Ah, seventy-nine, seventy-six, and then sevent...           40.82
# 14  Okay, next Jin Yingjuan told Jiao Enjun a terr...           49.66
# 15  Okay, next Jin Yingjuan told Jiao Enjun a terr...           49.66
# 16  Well, 797673, Jin Yingjuan told Jiao Enjun a t...           58.10
# 17  Well, 797673, Jin Yingjuan told Jiao Enjun a t...           58.10
# 18  OK, continue. Zhang Yining makes tea for Zhu Y...           65.36
# 19  OK, continue. Zhang Yining makes tea for Zhu Y...           65.36
#
#     sentence_end  speaker_id  type_sentence class_word
# 0         19.600           0     list_names       none
# 1         19.600           0     list_names       none
# 2         19.600           0     list_names       none
# 3         19.600           0     list_names       none
# 4         19.600           0     list_names       none
# 5         30.260           1     list_names       none
# 6         30.260           1     list_names       none
# 7         30.260           1     list_names       none
# 8         30.260           1     list_names       none
# 9         30.260           1     list_names       none
# 10        39.700           0  real_sentence    subject
# 11        39.700           0  real_sentence     object
# 12        49.560           1  real_sentence    subject
# 13        49.560           1  real_sentence     object
# 14        57.920           0  real_sentence     object
# 15        57.920           0  real_sentence    subject
# 16        65.239           1  real_sentence     object
# 17        65.239           1  real_sentence    subject
# 18        71.460           0  real_sentence     object
# 19        71.460           0  real_sentence    subject

# %%
import json
import re
import os 
import pandas as pd

#Paths
#folder_base = r"C:\Users\ingri\Documents\IMIM\experiments\RJH006_subj_obj"
#experiment_name = "RJH006_subj_obj"
#json_path = f"{folder_base}/{experiment_name}_transcription.json"
csv_path = r"C:\Users\ingri\Documents\IMIM\experiments\RJH006_subj_obj\RJH006_subj_obj_names_timestamps_CSV_NEW.csv"
df = pd.read_csv(csv_path)

#Names to find
names = [
    {"name_chin": "朱茵", "name_eng": "Zhu Yin"},
    {"name_chin": "焦恩俊", "name_eng": "Jiao Enjun"},
    {"name_chin": "周星驰", "name_eng": "Stephen Chow"},
    {"name_chin": "金映娟", "name_eng": "Jin Yingjuan"},
    {"name_chin": "张怡宁", "name_eng": "Zhang Yining"},
]

#names_chin = []
ids_names = []

#loop through unique sentences
for sentence in df["chinese_sentence"].unique():
    sentence_dicts = []
    total_count = 0

    #verifying names in sentence
    for name in names:
        n = name["name_chin"]
        if n in sentence:
            id_name = sentence.find(n)
            sentence_dicts.append({
                "sentence": sentence,
                "name": n,
                "id_name": id_name
            })
            total_count += sentence.count(n)
    
    #sentence type classification
    type_sentence = "list_names" if total_count > 2 else "real_sentence"

    #updating sentence dicts (type)
    for dic in sentence_dicts: 
        dic["type_sentence"] = type_sentence

        print(dic)
# Out:
# {'sentence': '朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。', 'name': '朱茵', 'id_name': 0, 'type_sentence': 'list_names'}
# {'sentence': '朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。', 'name': '焦恩俊', 'id_name': 3, 'type_sentence': 'list_names'}
# {'sentence': '朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。', 'name': '周星驰', 'id_name': 7, 'type_sentence': 'list_names'}
# {'sentence': '朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。', 'name': '金映娟', 'id_name': 11, 'type_sentence': 'list_names'}
# {'sentence': '朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。', 'name': '张怡宁', 'id_name': 15, 'type_sentence': 'list_names'}
# {'sentence': '啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。', 'name': '朱茵', 'id_name': 9, 'type_sentence': 'list_names'}
# {'sentence': '啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。', 'name': '焦恩俊', 'id_name': 12, 'type_sentence': 'list_names'}
# {'sentence': '啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。', 'name': '周星驰', 'id_name': 20, 'type_sentence': 'list_names'}
# {'sentence': '啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。', 'name': '金映娟', 'id_name': 16, 'type_sentence': 'list_names'}
# {'sentence': '啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。', 'name': '张怡宁', 'id_name': 24, 'type_sentence': 'list_names'}
# {'sentence': '好，我们下一个计算。接下来是个句子，朱茵教周星驰跳舞，八十二。', 'name': '朱茵', 'id_name': 18, 'type_sentence': 'real_sentence'}
# {'sentence': '好，我们下一个计算。接下来是个句子，朱茵教周星驰跳舞，八十二。', 'name': '周星驰', 'id_name': 21, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，七十九、七十六，再然后七十三，朱茵教周星驰跳舞。', 'name': '朱茵', 'id_name': 17, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，七十九、七十六，再然后七十三，朱茵教周星驰跳舞。', 'name': '周星驰', 'id_name': 20, 'type_sentence': 'real_sentence'}
# {'sentence': '好的，接下来金映娟告诉焦恩俊了一个可怕的秘密，八十二。', 'name': '焦恩俊', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '好的，接下来金映娟告诉焦恩俊了一个可怕的秘密，八十二。', 'name': '金映娟', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '嗯，七九七六七三，金映娟告诉了焦恩俊一个可怕的秘密。', 'name': '焦恩俊', 'id_name': 15, 'type_sentence': 'real_sentence'}
# {'sentence': '嗯，七九七六七三，金映娟告诉了焦恩俊一个可怕的秘密。', 'name': '金映娟', 'id_name': 9, 'type_sentence': 'real_sentence'}
# {'sentence': '好，继续。张怡宁给朱茵泡茶，二十四。', 'name': '朱茵', 'id_name': 9, 'type_sentence': 'real_sentence'}
# {'sentence': '好，继续。张怡宁给朱茵泡茶，二十四。', 'name': '张怡宁', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，二一十八、十五，张怡宁给朱茵泡茶。', 'name': '朱茵', 'id_name': 14, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，二一十八、十五，张怡宁给朱茵泡茶。', 'name': '张怡宁', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰邀请金映娟一起去听演唱会，五十九。', 'name': '周星驰', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰邀请金映娟一起去听演唱会，五十九。', 'name': '金映娟', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，五十六、五十三、五十，周星驰邀请金映娟一起去听演唱会。', 'name': '周星驰', 'id_name': 13, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，五十六、五十三、五十，周星驰邀请金映娟一起去听演唱会。', 'name': '金映娟', 'id_name': 18, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊把张怡宁从午睡中叫醒，四十一。', 'name': '焦恩俊', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊把张怡宁从午睡中叫醒，四十一。', 'name': '张怡宁', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，三十八、三十五、三十三，焦恩俊把张怡宁从午睡中叫醒。', 'name': '焦恩俊', 'id_name': 14, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，三十八、三十五、三十三，焦恩俊把张怡宁从午睡中叫醒。', 'name': '张怡宁', 'id_name': 18, 'type_sentence': 'real_sentence'}
# {'sentence': '好，接下来回答我一个问题哦，谁告诉焦恩俊了一个可怕的秘密？', 'name': '焦恩俊', 'id_name': 17, 'type_sentence': 'real_sentence'}
# {'sentence': '谁告诉过焦恩俊一个可怕的秘密？', 'name': '焦恩俊', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '嗯，这个我想想。哦，金映娟，应该是。', 'name': '金映娟', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰、金映娟、张怡宁、焦恩俊、朱茵，七十二。', 'name': '朱茵', 'id_name': 16, 'type_sentence': 'list_names'}
# {'sentence': '周星驰、金映娟、张怡宁、焦恩俊、朱茵，七十二。', 'name': '焦恩俊', 'id_name': 12, 'type_sentence': 'list_names'}
# {'sentence': '周星驰、金映娟、张怡宁、焦恩俊、朱茵，七十二。', 'name': '周星驰', 'id_name': 0, 'type_sentence': 'list_names'}
# {'sentence': '周星驰、金映娟、张怡宁、焦恩俊、朱茵，七十二。', 'name': '金映娟', 'id_name': 4, 'type_sentence': 'list_names'}
# {'sentence': '周星驰、金映娟、张怡宁、焦恩俊、朱茵，七十二。', 'name': '张怡宁', 'id_name': 8, 'type_sentence': 'list_names'}
# {'sentence': '啊，六十九、六十六，再然后六十三，周星驰、金映娟，然后，啊，再后焦恩俊，呃，呃，朱茵，再后张怡宁。', 'name': '朱茵', 'id_name': 40, 'type_sentence': 'list_names'}
# {'sentence': '啊，六十九、六十六，再然后六十三，周星驰、金映娟，然后，啊，再后焦恩俊，呃，呃，朱茵，再后张怡宁。', 'name': '焦恩俊', 'id_name': 32, 'type_sentence': 'list_names'}
# {'sentence': '啊，六十九、六十六，再然后六十三，周星驰、金映娟，然后，啊，再后焦恩俊，呃，呃，朱茵，再后张怡宁。', 'name': '周星驰', 'id_name': 17, 'type_sentence': 'list_names'}
# {'sentence': '啊，六十九、六十六，再然后六十三，周星驰、金映娟，然后，啊，再后焦恩俊，呃，呃，朱茵，再后张怡宁。', 'name': '金映娟', 'id_name': 21, 'type_sentence': 'list_names'}
# {'sentence': '啊，六十九、六十六，再然后六十三，周星驰、金映娟，然后，啊，再后焦恩俊，呃，呃，朱茵，再后张怡宁。', 'name': '张怡宁', 'id_name': 45, 'type_sentence': 'list_names'}
# {'sentence': '朱茵请焦恩俊吃晚饭，九十六。', 'name': '朱茵', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵请焦恩俊吃晚饭，九十六。', 'name': '焦恩俊', 'id_name': 3, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，九十三、九十八十七，朱茵请焦恩俊吃晚饭。', 'name': '朱茵', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，九十三、九十八十七，朱茵请焦恩俊吃晚饭。', 'name': '焦恩俊', 'id_name': 15, 'type_sentence': 'real_sentence'}
# {'sentence': '好，金映娟帮周星驰修电脑，六十四。', 'name': '周星驰', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '好，金映娟帮周星驰修电脑，六十四。', 'name': '金映娟', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，六十一、五十八、五十五，金映娟帮周星驰修电脑.好。', 'name': '周星驰', 'id_name': 18, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，六十一、五十八、五十五，金映娟帮周星驰修电脑.好。', 'name': '金映娟', 'id_name': 14, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊给张怡宁写诗，二十九。', 'name': '焦恩俊', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊给张怡宁写诗，二十九。', 'name': '张怡宁', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '哦，二六二三二十，呃，焦恩俊给张怡宁写诗。', 'name': '焦恩俊', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '哦，二六二三二十，呃，焦恩俊给张怡宁写诗。', 'name': '张怡宁', 'id_name': 15, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰送金映娟去欧洲旅游，七十九。', 'name': '周星驰', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰送金映娟去欧洲旅游，七十九。', 'name': '金映娟', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '七六七三七零，周星驰送金映娟去欧洲旅游。', 'name': '周星驰', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '七六七三七零，周星驰送金映娟去欧洲旅游。', 'name': '金映娟', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁和朱茵争论，六十。', 'name': '朱茵', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁和朱茵争论，六十。', 'name': '张怡宁', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，五七五四五一，张怡宁和朱茵进行争论。', 'name': '朱茵', 'id_name': 13, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，五七五四五一，张怡宁和朱茵进行争论。', 'name': '张怡宁', 'id_name': 9, 'type_sentence': 'real_sentence'}
# {'sentence': '好，回答，我回答我一个问题。谁邀请焦恩俊吃晚饭？', 'name': '焦恩俊', 'id_name': 17, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，谁邀请焦恩俊吃晚饭？呃，这个，啊，邀请焦恩俊吃晚饭。哦，这个我不记得，不好意思啊！嗯。', 'name': '焦恩俊', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '好，接下来下一个，还是先从名字开始啊。周星驰、金映娟、朱茵、张怡宁、焦恩俊，四十四。', 'name': '朱茵', 'id_name': 27, 'type_sentence': 'list_names'}
# {'sentence': '好，接下来下一个，还是先从名字开始啊。周星驰、金映娟、朱茵、张怡宁、焦恩俊，四十四。', 'name': '焦恩俊', 'id_name': 34, 'type_sentence': 'list_names'}
# {'sentence': '好，接下来下一个，还是先从名字开始啊。周星驰、金映娟、朱茵、张怡宁、焦恩俊，四十四。', 'name': '周星驰', 'id_name': 19, 'type_sentence': 'list_names'}
# {'sentence': '好，接下来下一个，还是先从名字开始啊。周星驰、金映娟、朱茵、张怡宁、焦恩俊，四十四。', 'name': '金映娟', 'id_name': 23, 'type_sentence': 'list_names'}
# {'sentence': '好，接下来下一个，还是先从名字开始啊。周星驰、金映娟、朱茵、张怡宁、焦恩俊，四十四。', 'name': '张怡宁', 'id_name': 30, 'type_sentence': 'list_names'}
# {'sentence': '嗯，四十三，哦不是哦，四十一、三十八，还有三十五。周星驰，朱茵，呃，焦恩俊，金映娟，张怡宁。', 'name': '朱茵', 'id_name': 29, 'type_sentence': 'list_names'}
# {'sentence': '嗯，四十三，哦不是哦，四十一、三十八，还有三十五。周星驰，朱茵，呃，焦恩俊，金映娟，张怡宁。', 'name': '焦恩俊', 'id_name': 34, 'type_sentence': 'list_names'}
# {'sentence': '嗯，四十三，哦不是哦，四十一、三十八，还有三十五。周星驰，朱茵，呃，焦恩俊，金映娟，张怡宁。', 'name': '周星驰', 'id_name': 25, 'type_sentence': 'list_names'}
# {'sentence': '嗯，四十三，哦不是哦，四十一、三十八，还有三十五。周星驰，朱茵，呃，焦恩俊，金映娟，张怡宁。', 'name': '金映娟', 'id_name': 38, 'type_sentence': 'list_names'}
# {'sentence': '嗯，四十三，哦不是哦，四十一、三十八，还有三十五。周星驰，朱茵，呃，焦恩俊，金映娟，张怡宁。', 'name': '张怡宁', 'id_name': 42, 'type_sentence': 'list_names'}
# {'sentence': '好，接下来是句子。焦恩俊给朱茵唱歌，九十。', 'name': '朱茵', 'id_name': 13, 'type_sentence': 'real_sentence'}
# {'sentence': '好，接下来是句子。焦恩俊给朱茵唱歌，九十。', 'name': '焦恩俊', 'id_name': 9, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，八十七、八十四、八十一，焦恩俊给朱茵，朱茵唱歌。', 'name': '朱茵', 'id_name': 18, 'type_sentence': 'list_names'}
# {'sentence': '呃，八十七、八十四、八十一，焦恩俊给朱茵，朱茵唱歌。', 'name': '焦恩俊', 'id_name': 14, 'type_sentence': 'list_names'}
# {'sentence': '好，对，好，接下来计算。张怡宁给金映娟买冰激凌，四十六。', 'name': '金映娟', 'id_name': 16, 'type_sentence': 'real_sentence'}
# {'sentence': '好，对，好，接下来计算。张怡宁给金映娟买冰激凌，四十六。', 'name': '张怡宁', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '四十三、四十、三十七，张怡宁给金映娟买冰淇淋。', 'name': '金映娟', 'id_name': 15, 'type_sentence': 'real_sentence'}
# {'sentence': '四十三、四十、三十七，张怡宁给金映娟买冰淇淋。', 'name': '张怡宁', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '对，好，周星驰给焦恩俊推荐了一本书，五十九。', 'name': '焦恩俊', 'id_name': 8, 'type_sentence': 'real_sentence'}
# {'sentence': '对，好，周星驰给焦恩俊推荐了一本书，五十九。', 'name': '周星驰', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '五十六、五十三、五十，周星驰给焦恩俊推荐了一本书。', 'name': '焦恩俊', 'id_name': 15, 'type_sentence': 'real_sentence'}
# {'sentence': '五十六、五十三、五十，周星驰给焦恩俊推荐了一本书。', 'name': '周星驰', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '好。金映娟紧紧地抱着-', 'name': '金映娟', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '七十九。七十六。七十三。金玉娇紧紧地抱住了张怡宁。', 'name': '张怡宁', 'id_name': 21, 'type_sentence': 'real_sentence'}
# {'sentence': '花了一个朱茵给周星驰提建议九十九。', 'name': '朱茵', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '花了一个朱茵给周星驰提建议九十九。', 'name': '周星驰', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '九十六九十三九十朱茵给周星驰提建议。', 'name': '朱茵', 'id_name': 8, 'type_sentence': 'real_sentence'}
# {'sentence': '九十六九十三九十朱茵给周星驰提建议。', 'name': '周星驰', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '好，接下来回答我一个问题，谁给朱茵唱歌？', 'name': '朱茵', 'id_name': 15, 'type_sentence': 'real_sentence'}
# {'sentence': '嗯嗯。焦恩俊吧，应该是对的。', 'name': '焦恩俊', 'id_name': 3, 'type_sentence': 'real_sentence'}
# {'sentence': '好，接下来还是从名字开始啊。金映娟、朱茵、焦恩俊、周星驰、张怡宁四十。', 'name': '朱茵', 'id_name': 18, 'type_sentence': 'list_names'}
# {'sentence': '好，接下来还是从名字开始啊。金映娟、朱茵、焦恩俊、周星驰、张怡宁四十。', 'name': '焦恩俊', 'id_name': 21, 'type_sentence': 'list_names'}
# {'sentence': '好，接下来还是从名字开始啊。金映娟、朱茵、焦恩俊、周星驰、张怡宁四十。', 'name': '周星驰', 'id_name': 25, 'type_sentence': 'list_names'}
# {'sentence': '好，接下来还是从名字开始啊。金映娟、朱茵、焦恩俊、周星驰、张怡宁四十。', 'name': '金映娟', 'id_name': 14, 'type_sentence': 'list_names'}
# {'sentence': '好，接下来还是从名字开始啊。金映娟、朱茵、焦恩俊、周星驰、张怡宁四十。', 'name': '张怡宁', 'id_name': 29, 'type_sentence': 'list_names'}
# {'sentence': '三十七、三十四、三十一金映娟、焦恩俊、朱茵、张怡宁、周星驰。', 'name': '朱茵', 'id_name': 19, 'type_sentence': 'list_names'}
# {'sentence': '三十七、三十四、三十一金映娟、焦恩俊、朱茵、张怡宁、周星驰。', 'name': '焦恩俊', 'id_name': 15, 'type_sentence': 'list_names'}
# {'sentence': '三十七、三十四、三十一金映娟、焦恩俊、朱茵、张怡宁、周星驰。', 'name': '周星驰', 'id_name': 26, 'type_sentence': 'list_names'}
# {'sentence': '三十七、三十四、三十一金映娟、焦恩俊、朱茵、张怡宁、周星驰。', 'name': '金映娟', 'id_name': 11, 'type_sentence': 'list_names'}
# {'sentence': '三十七、三十四、三十一金映娟、焦恩俊、朱茵、张怡宁、周星驰。', 'name': '张怡宁', 'id_name': 22, 'type_sentence': 'list_names'}
# {'sentence': '周星驰借给焦恩俊钱二十六。', 'name': '焦恩俊', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰借给焦恩俊钱二十六。', 'name': '周星驰', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '二三二十十七周星驰借给焦恩俊钱，给焦恩俊借钱。好的。', 'name': '焦恩俊', 'id_name': 11, 'type_sentence': 'list_names'}
# {'sentence': '二三二十十七周星驰借给焦恩俊钱，给焦恩俊借钱。好的。', 'name': '周星驰', 'id_name': 6, 'type_sentence': 'list_names'}
# {'sentence': '对，好！朱茵下象棋打败了金映娟七十一。', 'name': '朱茵', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '对，好！朱茵下象棋打败了金映娟七十一。', 'name': '金映娟', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '六十八、六十五、六十二朱茵下象棋打败了金映娟。', 'name': '朱茵', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '六十八、六十五、六十二朱茵下象棋打败了金映娟。', 'name': '金映娟', 'id_name': 19, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁给周星驰一盆花。十二。', 'name': '周星驰', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁给周星驰一盆花。十二。', 'name': '张怡宁', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '九六三张怡宁给周星驰一盆花。', 'name': '周星驰', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '九六三张怡宁给周星驰一盆花。', 'name': '张怡宁', 'id_name': 3, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊给朱茵自己的签名照。二十。', 'name': '朱茵', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊给朱茵自己的签名照。二十。', 'name': '焦恩俊', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '十七十四十一焦恩俊给给张怡宁自己的签名照。', 'name': '焦恩俊', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '十七十四十一焦恩俊给给张怡宁自己的签名照。', 'name': '张怡宁', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '好，金映娟教张怡宁做数学题三十一。', 'name': '金映娟', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '好，金映娟教张怡宁做数学题三十一。', 'name': '张怡宁', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '二八二五二二金映娟教张怡宁做数学题。', 'name': '金映娟', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '二八二五二二金映娟教张怡宁做数学题。', 'name': '张怡宁', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '接下来回答谁下象棋打败了金映娟？', 'name': '金映娟', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '嗯，哦，张怡宁啊，应该是。', 'name': '张怡宁', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '好，我们继续啊！接下来还是先名字，焦恩俊、张怡宁、金映娟、朱茵、周星驰八十七。', 'name': '朱茵', 'id_name': 29, 'type_sentence': 'list_names'}
# {'sentence': '好，我们继续啊！接下来还是先名字，焦恩俊、张怡宁、金映娟、朱茵、周星驰八十七。', 'name': '焦恩俊', 'id_name': 17, 'type_sentence': 'list_names'}
# {'sentence': '好，我们继续啊！接下来还是先名字，焦恩俊、张怡宁、金映娟、朱茵、周星驰八十七。', 'name': '周星驰', 'id_name': 32, 'type_sentence': 'list_names'}
# {'sentence': '好，我们继续啊！接下来还是先名字，焦恩俊、张怡宁、金映娟、朱茵、周星驰八十七。', 'name': '金映娟', 'id_name': 25, 'type_sentence': 'list_names'}
# {'sentence': '好，我们继续啊！接下来还是先名字，焦恩俊、张怡宁、金映娟、朱茵、周星驰八十七。', 'name': '张怡宁', 'id_name': 21, 'type_sentence': 'list_names'}
# {'sentence': '八十四、八十一、八十焦恩俊、张怡宁、朱茵、金映娟、周星驰。', 'name': '朱茵', 'id_name': 18, 'type_sentence': 'list_names'}
# {'sentence': '八十四、八十一、八十焦恩俊、张怡宁、朱茵、金映娟、周星驰。', 'name': '焦恩俊', 'id_name': 10, 'type_sentence': 'list_names'}
# {'sentence': '八十四、八十一、八十焦恩俊、张怡宁、朱茵、金映娟、周星驰。', 'name': '周星驰', 'id_name': 25, 'type_sentence': 'list_names'}
# {'sentence': '八十四、八十一、八十焦恩俊、张怡宁、朱茵、金映娟、周星驰。', 'name': '金映娟', 'id_name': 21, 'type_sentence': 'list_names'}
# {'sentence': '八十四、八十一、八十焦恩俊、张怡宁、朱茵、金映娟、周星驰。', 'name': '张怡宁', 'id_name': 14, 'type_sentence': 'list_names'}
# {'sentence': '好，张怡宁偷焦恩俊的钱包三十三。', 'name': '焦恩俊', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '好，张怡宁偷焦恩俊的钱包三十三。', 'name': '张怡宁', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '三十二期二四焦恩俊偷张怡宁的钱包。', 'name': '焦恩俊', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '三十二期二四焦恩俊偷张怡宁的钱包。', 'name': '张怡宁', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '金映娟给朱茵一个球九十八。', 'name': '朱茵', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '金映娟给朱茵一个球九十八。', 'name': '金映娟', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '九五九二八九金映娟给朱茵一个球。', 'name': '朱茵', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '九五九二八九金映娟给朱茵一个球。', 'name': '金映娟', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰给张怡宁做咖啡二十八。', 'name': '周星驰', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰给张怡宁做咖啡二十八。', 'name': '张怡宁', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '二五二二十九周星驰给张怡宁做咖啡。', 'name': '周星驰', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '二五二二十九周星驰给张怡宁做咖啡。', 'name': '张怡宁', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵帮金映娟照顾狗二十八。', 'name': '朱茵', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵帮金映娟照顾狗二十八。', 'name': '金映娟', 'id_name': 3, 'type_sentence': 'real_sentence'}
# {'sentence': '二五二二十九朱茵帮金映娟照顾狗。', 'name': '朱茵', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '二五二二十九朱茵帮金映娟照顾狗。', 'name': '金映娟', 'id_name': 9, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊请周星驰帮忙四十三。', 'name': '焦恩俊', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊请周星驰帮忙四十三。', 'name': '周星驰', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '四十三四十三四焦恩俊请周星驰帮忙。', 'name': '焦恩俊', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '四十三四十三四焦恩俊请周星驰帮忙。', 'name': '周星驰', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '谁给了朱茵一个球？', 'name': '朱茵', 'id_name': 3, 'type_sentence': 'real_sentence'}
# {'sentence': '谁给了朱茵一个球？嗯，谁给了朱茵一个球？嗯，金映娟嘛，应该是给朱茵一个球。对！好，我们继续啊！你办了什么？哦，好，还是从名字开始。张怡宁、朱茵、周星驰、金映娟、焦恩俊、九-六三零，张怡宁、朱茵、焦恩俊、金映娟、金映娟，然后周星驰。', 'name': '朱茵', 'id_name': 3, 'type_sentence': 'list_names'}
# {'sentence': '谁给了朱茵一个球？嗯，谁给了朱茵一个球？嗯，金映娟嘛，应该是给朱茵一个球。对！好，我们继续啊！你办了什么？哦，好，还是从名字开始。张怡宁、朱茵、周星驰、金映娟、焦恩俊、九-六三零，张怡宁、朱茵、焦恩俊、金映娟、金映娟，然后周星驰。', 'name': '焦恩俊', 'id_name': 80, 'type_sentence': 'list_names'}
# {'sentence': '谁给了朱茵一个球？嗯，谁给了朱茵一个球？嗯，金映娟嘛，应该是给朱茵一个球。对！好，我们继续啊！你办了什么？哦，好，还是从名字开始。张怡宁、朱茵、周星驰、金映娟、焦恩俊、九-六三零，张怡宁、朱茵、焦恩俊、金映娟、金映娟，然后周星驰。', 'name': '周星驰', 'id_name': 72, 'type_sentence': 'list_names'}
# {'sentence': '谁给了朱茵一个球？嗯，谁给了朱茵一个球？嗯，金映娟嘛，应该是给朱茵一个球。对！好，我们继续啊！你办了什么？哦，好，还是从名字开始。张怡宁、朱茵、周星驰、金映娟、焦恩俊、九-六三零，张怡宁、朱茵、焦恩俊、金映娟、金映娟，然后周星驰。', 'name': '金映娟', 'id_name': 22, 'type_sentence': 'list_names'}
# {'sentence': '谁给了朱茵一个球？嗯，谁给了朱茵一个球？嗯，金映娟嘛，应该是给朱茵一个球。对！好，我们继续啊！你办了什么？哦，好，还是从名字开始。张怡宁、朱茵、周星驰、金映娟、焦恩俊、九-六三零，张怡宁、朱茵、焦恩俊、金映娟、金映娟，然后周星驰。', 'name': '张怡宁', 'id_name': 65, 'type_sentence': 'list_names'}
# {'sentence': '焦恩俊借给张怡宁他的车。四十五。', 'name': '焦恩俊', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊借给张怡宁他的车。四十五。', 'name': '张怡宁', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '四二三九三六焦恩俊借给张怡宁他的车。', 'name': '焦恩俊', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '四二三九三六焦恩俊借给张怡宁他的车。', 'name': '张怡宁', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '金映娟跟朱茵握手。三十三四三一二八金映娟跟朱茵握手，周星驰不小心推了焦恩俊。', 'name': '朱茵', 'id_name': 4, 'type_sentence': 'list_names'}
# {'sentence': '金映娟跟朱茵握手。三十三四三一二八金映娟跟朱茵握手，周星驰不小心推了焦恩俊。', 'name': '焦恩俊', 'id_name': 34, 'type_sentence': 'list_names'}
# {'sentence': '金映娟跟朱茵握手。三十三四三一二八金映娟跟朱茵握手，周星驰不小心推了焦恩俊。', 'name': '周星驰', 'id_name': 26, 'type_sentence': 'list_names'}
# {'sentence': '金映娟跟朱茵握手。三十三四三一二八金映娟跟朱茵握手，周星驰不小心推了焦恩俊。', 'name': '金映娟', 'id_name': 0, 'type_sentence': 'list_names'}
# {'sentence': '八十八六八三八0周星驰不小心推了焦恩俊。', 'name': '焦恩俊', 'id_name': 16, 'type_sentence': 'real_sentence'}
# {'sentence': '八十八六八三八0周星驰不小心推了焦恩俊。', 'name': '周星驰', 'id_name': 8, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵陪金映娟去看医生。', 'name': '朱茵', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵陪金映娟去看医生。', 'name': '金映娟', 'id_name': 3, 'type_sentence': 'real_sentence'}
# {'sentence': '五十二、四十九、四十六、四十三嗯，周星驰陪金映娟去看，金映娟去看病，还是什么？', 'name': '周星驰', 'id_name': 17, 'type_sentence': 'list_names'}
# {'sentence': '五十二、四十九、四十六、四十三嗯，周星驰陪金映娟去看，金映娟去看病，还是什么？', 'name': '金映娟', 'id_name': 21, 'type_sentence': 'list_names'}
# {'sentence': '好，接下来张怡宁从机场接周星驰。', 'name': '周星驰', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '好，接下来张怡宁从机场接周星驰。', 'name': '张怡宁', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '九十七、九十四、九十一、八十八张怡宁从机场接周星驰。', 'name': '周星驰', 'id_name': 22, 'type_sentence': 'real_sentence'}
# {'sentence': '九十七、九十四、九十一、八十八张怡宁从机场接周星驰。', 'name': '张怡宁', 'id_name': 15, 'type_sentence': 'real_sentence'}
# {'sentence': '好，接下来回答我谁借给张怡宁他的车？', 'name': '张怡宁', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '嗯？谁借给张怡宁他的车？嗯，我想想啊，啊，朱茵嘛，应该是。', 'name': '朱茵', 'id_name': 21, 'type_sentence': 'real_sentence'}
# {'sentence': '嗯？谁借给张怡宁他的车？嗯，我想想啊，啊，朱茵嘛，应该是。', 'name': '张怡宁', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁、周星驰、朱茵、焦恩俊、金映娟，四十二。', 'name': '朱茵', 'id_name': 8, 'type_sentence': 'list_names'}
# {'sentence': '张怡宁、周星驰、朱茵、焦恩俊、金映娟，四十二。', 'name': '焦恩俊', 'id_name': 11, 'type_sentence': 'list_names'}
# {'sentence': '张怡宁、周星驰、朱茵、焦恩俊、金映娟，四十二。', 'name': '周星驰', 'id_name': 4, 'type_sentence': 'list_names'}
# {'sentence': '张怡宁、周星驰、朱茵、焦恩俊、金映娟，四十二。', 'name': '金映娟', 'id_name': 15, 'type_sentence': 'list_names'}
# {'sentence': '张怡宁、周星驰、朱茵、焦恩俊、金映娟，四十二。', 'name': '张怡宁', 'id_name': 0, 'type_sentence': 'list_names'}
# {'sentence': '三九三六三三二张怡宁，朱茵,周星驰，焦恩俊，金映娟。', 'name': '朱茵', 'id_name': 11, 'type_sentence': 'list_names'}
# {'sentence': '三九三六三三二张怡宁，朱茵,周星驰，焦恩俊，金映娟。', 'name': '焦恩俊', 'id_name': 18, 'type_sentence': 'list_names'}
# {'sentence': '三九三六三三二张怡宁，朱茵,周星驰，焦恩俊，金映娟。', 'name': '周星驰', 'id_name': 14, 'type_sentence': 'list_names'}
# {'sentence': '三九三六三三二张怡宁，朱茵,周星驰，焦恩俊，金映娟。', 'name': '金映娟', 'id_name': 22, 'type_sentence': 'list_names'}
# {'sentence': '三九三六三三二张怡宁，朱茵,周星驰，焦恩俊，金映娟。', 'name': '张怡宁', 'id_name': 7, 'type_sentence': 'list_names'}
# {'sentence': '金映娟借给张怡宁自行车，二十三。', 'name': '金映娟', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '金映娟借给张怡宁自行车，二十三。', 'name': '张怡宁', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '二十十七十四，金映娟借给张怡宁自行车。', 'name': '金映娟', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '二十十七十四，金映娟借给张怡宁自行车。', 'name': '张怡宁', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵卖给焦恩俊一把吉他，八十四。', 'name': '朱茵', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵卖给焦恩俊一把吉他，八十四。', 'name': '焦恩俊', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '八一七八七五，朱茵卖给焦恩俊一把吉他。', 'name': '朱茵', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '八一七八七五，朱茵卖给焦恩俊一把吉他。', 'name': '焦恩俊', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁祝周星驰生日快乐，二十五。', 'name': '周星驰', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁祝周星驰生日快乐，二十五。', 'name': '张怡宁', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '二十二十九十六，张怡宁祝周星驰生日快乐。', 'name': '周星驰', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '二十二十九十六，张怡宁祝周星驰生日快乐。', 'name': '张怡宁', 'id_name': 8, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊借给朱茵帽子，六十八。', 'name': '朱茵', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊借给朱茵帽子，六十八。', 'name': '焦恩俊', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰给金映娟道歉，六十。', 'name': '周星驰', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰给金映娟道歉，六十。', 'name': '金映娟', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '五七五四五一，周星驰给金映娟道歉。', 'name': '周星驰', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '五七五四五一，周星驰给金映娟道歉。', 'name': '金映娟', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '谁给金映娟道歉？', 'name': '金映娟', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '啊，周星驰。', 'name': '周星驰', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '还从名字开始啊。金映娟、张怡宁、朱茵、周星驰、焦恩俊，五十四。', 'name': '朱茵', 'id_name': 16, 'type_sentence': 'list_names'}
# {'sentence': '还从名字开始啊。金映娟、张怡宁、朱茵、周星驰、焦恩俊，五十四。', 'name': '焦恩俊', 'id_name': 23, 'type_sentence': 'list_names'}
# {'sentence': '还从名字开始啊。金映娟、张怡宁、朱茵、周星驰、焦恩俊，五十四。', 'name': '周星驰', 'id_name': 19, 'type_sentence': 'list_names'}
# {'sentence': '还从名字开始啊。金映娟、张怡宁、朱茵、周星驰、焦恩俊，五十四。', 'name': '金映娟', 'id_name': 8, 'type_sentence': 'list_names'}
# {'sentence': '还从名字开始啊。金映娟、张怡宁、朱茵、周星驰、焦恩俊，五十四。', 'name': '张怡宁', 'id_name': 12, 'type_sentence': 'list_names'}
# {'sentence': '呃，五一四八四五，金映娟、张怡宁、朱茵、周星驰、焦恩俊。', 'name': '朱茵', 'id_name': 17, 'type_sentence': 'list_names'}
# {'sentence': '呃，五一四八四五，金映娟、张怡宁、朱茵、周星驰、焦恩俊。', 'name': '焦恩俊', 'id_name': 24, 'type_sentence': 'list_names'}
# {'sentence': '呃，五一四八四五，金映娟、张怡宁、朱茵、周星驰、焦恩俊。', 'name': '周星驰', 'id_name': 20, 'type_sentence': 'list_names'}
# {'sentence': '呃，五一四八四五，金映娟、张怡宁、朱茵、周星驰、焦恩俊。', 'name': '金映娟', 'id_name': 9, 'type_sentence': 'list_names'}
# {'sentence': '呃，五一四八四五，金映娟、张怡宁、朱茵、周星驰、焦恩俊。', 'name': '张怡宁', 'id_name': 13, 'type_sentence': 'list_names'}
# {'sentence': '朱茵给张怡宁拍照，二十三。', 'name': '朱茵', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵给张怡宁拍照，二十三。', 'name': '张怡宁', 'id_name': 3, 'type_sentence': 'real_sentence'}
# {'sentence': '二十十七十四，朱茵给张怡宁拍照。', 'name': '朱茵', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '二十十七十四，朱茵给张怡宁拍照。', 'name': '张怡宁', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '金映娟跟焦恩俊打招呼，六十一。', 'name': '焦恩俊', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '金映娟跟焦恩俊打招呼，六十一。', 'name': '金映娟', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '五十八五十五五十二，金映娟跟张--跟焦恩俊打招呼。', 'name': '焦恩俊', 'id_name': 18, 'type_sentence': 'real_sentence'}
# {'sentence': '五十八五十五五十二，金映娟跟张--跟焦恩俊打招呼。', 'name': '金映娟', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰打了朱茵，四十七。', 'name': '朱茵', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰打了朱茵，四十七。', 'name': '周星驰', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，四十四四十一三十八，周星驰打了朱茵。', 'name': '朱茵', 'id_name': 17, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，四十四四十一三十八，周星驰打了朱茵。', 'name': '周星驰', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊给金映娟下面条吃，十八。', 'name': '焦恩俊', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊给金映娟下面条吃，十八。', 'name': '金映娟', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '十五十二九，焦恩俊给金映娟下面条吃。', 'name': '焦恩俊', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '十五十二九，焦恩俊给金映娟下面条吃。', 'name': '金映娟', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁给周星驰发了条消息，八十。', 'name': '周星驰', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁给周星驰发了条消息，八十。', 'name': '张怡宁', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '七七七四七一，张怡宁给周星驰发了一条消息。', 'name': '周星驰', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '七七七四七一，张怡宁给周星驰发了一条消息。', 'name': '张怡宁', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '谁给周星驰发的条消息？', 'name': '周星驰', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，张怡宁', 'name': '张怡宁', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '好，我们还有最后两个，还是从名字开始。周星驰、金映娟、朱茵、张怡宁、焦恩俊，九十。', 'name': '朱茵', 'id_name': 27, 'type_sentence': 'list_names'}
# {'sentence': '好，我们还有最后两个，还是从名字开始。周星驰、金映娟、朱茵、张怡宁、焦恩俊，九十。', 'name': '焦恩俊', 'id_name': 34, 'type_sentence': 'list_names'}
# {'sentence': '好，我们还有最后两个，还是从名字开始。周星驰、金映娟、朱茵、张怡宁、焦恩俊，九十。', 'name': '周星驰', 'id_name': 19, 'type_sentence': 'list_names'}
# {'sentence': '好，我们还有最后两个，还是从名字开始。周星驰、金映娟、朱茵、张怡宁、焦恩俊，九十。', 'name': '金映娟', 'id_name': 23, 'type_sentence': 'list_names'}
# {'sentence': '好，我们还有最后两个，还是从名字开始。周星驰、金映娟、朱茵、张怡宁、焦恩俊，九十。', 'name': '张怡宁', 'id_name': 30, 'type_sentence': 'list_names'}
# {'sentence': '嗯，八七八四八一，呃，周星驰，金映娟，呃，朱茵，焦恩俊，张怡宁。', 'name': '朱茵', 'id_name': 21, 'type_sentence': 'list_names'}
# {'sentence': '嗯，八七八四八一，呃，周星驰，金映娟，呃，朱茵，焦恩俊，张怡宁。', 'name': '焦恩俊', 'id_name': 24, 'type_sentence': 'list_names'}
# {'sentence': '嗯，八七八四八一，呃，周星驰，金映娟，呃，朱茵，焦恩俊，张怡宁。', 'name': '周星驰', 'id_name': 11, 'type_sentence': 'list_names'}
# {'sentence': '嗯，八七八四八一，呃，周星驰，金映娟，呃，朱茵，焦恩俊，张怡宁。', 'name': '金映娟', 'id_name': 15, 'type_sentence': 'list_names'}
# {'sentence': '嗯，八七八四八一，呃，周星驰，金映娟，呃，朱茵，焦恩俊，张怡宁。', 'name': '张怡宁', 'id_name': 28, 'type_sentence': 'list_names'}
# {'sentence': '好。张怡宁邀请周星驰一起跳舞，八十九。', 'name': '周星驰', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '好。张怡宁邀请周星驰一起跳舞，八十九。', 'name': '张怡宁', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '八六八三八零，张怡宁邀请周星驰一起跳。', 'name': '周星驰', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '八六八三八零，张怡宁邀请周星驰一起跳。', 'name': '张怡宁', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵借给金映娟书，五十二。', 'name': '朱茵', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵借给金映娟书，五十二。', 'name': '金映娟', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '四九四六四三，朱茵借给金映娟一本书。', 'name': '朱茵', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '四九四六四三，朱茵借给金映娟一本书。', 'name': '金映娟', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊给张怡宁他的伞，二十七。', 'name': '焦恩俊', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊给张怡宁他的伞，二十七。', 'name': '张怡宁', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '二四二三二四，张怡宁给朱茵，星驰他的伞。', 'name': '朱茵', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '二四二三二四，张怡宁给朱茵，星驰他的伞。', 'name': '张怡宁', 'id_name': 7, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰偷了朱茵的运动鞋，十九。', 'name': '朱茵', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰偷了朱茵的运动鞋，十九。', 'name': '周星驰', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '十六时三十，周星驰偷了，偷了朱茵的运动鞋。', 'name': '朱茵', 'id_name': 14, 'type_sentence': 'real_sentence'}
# {'sentence': '十六时三十，周星驰偷了，偷了朱茵的运动鞋。', 'name': '周星驰', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '金映娟祝贺焦恩俊毕业，十一。', 'name': '焦恩俊', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '金映娟祝贺焦恩俊毕业，十一。', 'name': '金映娟', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，八三五，金映娟祝贺焦恩俊毕业。', 'name': '焦恩俊', 'id_name': 11, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，八三五，金映娟祝贺焦恩俊毕业。', 'name': '金映娟', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '谁邀请周星驰一起跳舞？', 'name': '周星驰', 'id_name': 3, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，朱茵。', 'name': '朱茵', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '金映娟、张怡宁、焦恩俊、朱茵、周星驰，八十二。', 'name': '朱茵', 'id_name': 12, 'type_sentence': 'list_names'}
# {'sentence': '金映娟、张怡宁、焦恩俊、朱茵、周星驰，八十二。', 'name': '焦恩俊', 'id_name': 8, 'type_sentence': 'list_names'}
# {'sentence': '金映娟、张怡宁、焦恩俊、朱茵、周星驰，八十二。', 'name': '周星驰', 'id_name': 15, 'type_sentence': 'list_names'}
# {'sentence': '金映娟、张怡宁、焦恩俊、朱茵、周星驰，八十二。', 'name': '金映娟', 'id_name': 0, 'type_sentence': 'list_names'}
# {'sentence': '金映娟、张怡宁、焦恩俊、朱茵、周星驰，八十二。', 'name': '张怡宁', 'id_name': 4, 'type_sentence': 'list_names'}
# {'sentence': '呃，七十九七十六七十三，金映娟，焦恩俊，呃，周星驰，朱茵，张怡宁', 'name': '朱茵', 'id_name': 26, 'type_sentence': 'list_names'}
# {'sentence': '呃，七十九七十六七十三，金映娟，焦恩俊，呃，周星驰，朱茵，张怡宁', 'name': '焦恩俊', 'id_name': 16, 'type_sentence': 'list_names'}
# {'sentence': '呃，七十九七十六七十三，金映娟，焦恩俊，呃，周星驰，朱茵，张怡宁', 'name': '周星驰', 'id_name': 22, 'type_sentence': 'list_names'}
# {'sentence': '呃，七十九七十六七十三，金映娟，焦恩俊，呃，周星驰，朱茵，张怡宁', 'name': '金映娟', 'id_name': 12, 'type_sentence': 'list_names'}
# {'sentence': '呃，七十九七十六七十三，金映娟，焦恩俊，呃，周星驰，朱茵，张怡宁', 'name': '张怡宁', 'id_name': 29, 'type_sentence': 'list_names'}
# {'sentence': '好，继续走。金映娟给张怡宁准备早饭，十六。', 'name': '金映娟', 'id_name': 6, 'type_sentence': 'real_sentence'}
# {'sentence': '好，继续走。金映娟给张怡宁准备早饭，十六。', 'name': '张怡宁', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '石三石九，金映娟给张怡宁准备早饭。', 'name': '金映娟', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '石三石九，金映娟给张怡宁准备早饭。', 'name': '张怡宁', 'id_name': 9, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰给朱茵准备了惊喜礼物，七十七。', 'name': '朱茵', 'id_name': 4, 'type_sentence': 'real_sentence'}
# {'sentence': '周星驰给朱茵准备了惊喜礼物，七十七。', 'name': '周星驰', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，七十四七十一六十八，周星驰给金映娟准备了礼物。', 'name': '周星驰', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，七十四七十一六十八，周星驰给金映娟准备了礼物。', 'name': '金映娟', 'id_name': 16, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊打网球赢了金映娟，八十二。', 'name': '焦恩俊', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '焦恩俊打网球赢了金映娟，八十二。', 'name': '金映娟', 'id_name': 8, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，七十九七十六七十三，焦恩俊打网球赢了金映娟。', 'name': '焦恩俊', 'id_name': 12, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，七十九七十六七十三，焦恩俊打网球赢了金映娟。', 'name': '金映娟', 'id_name': 20, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵帮周星驰搬家，十七。', 'name': '朱茵', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '朱茵帮周星驰搬家，十七。', 'name': '周星驰', 'id_name': 3, 'type_sentence': 'real_sentence'}
# {'sentence': '十四，再然后，十三，再然后，十，朱茵帮周星驰搬家。', 'name': '朱茵', 'id_name': 16, 'type_sentence': 'real_sentence'}
# {'sentence': '十四，再然后，十三，再然后，十，朱茵帮周星驰搬家。', 'name': '周星驰', 'id_name': 19, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁借给焦恩俊笔，三十七。', 'name': '焦恩俊', 'id_name': 5, 'type_sentence': 'real_sentence'}
# {'sentence': '张怡宁借给焦恩俊笔，三十七。', 'name': '张怡宁', 'id_name': 0, 'type_sentence': 'real_sentence'}
# {'sentence': '三十四三十一二十八，张怡宁借给焦恩俊笔。', 'name': '焦恩俊', 'id_name': 15, 'type_sentence': 'real_sentence'}
# {'sentence': '三十四三十一二十八，张怡宁借给焦恩俊笔。', 'name': '张怡宁', 'id_name': 10, 'type_sentence': 'real_sentence'}
# {'sentence': '谁给张怡宁准备了早饭？', 'name': '张怡宁', 'id_name': 2, 'type_sentence': 'real_sentence'}
# {'sentence': '呃，谁给张怡宁准备了早饭？呃，金映娟给张怡宁准备了早饭。', 'name': '金映娟', 'id_name': 15, 'type_sentence': 'list_names'}
# {'sentence': '呃，谁给张怡宁准备了早饭？呃，金映娟给张怡宁准备了早饭。', 'name': '张怡宁', 'id_name': 4, 'type_sentence': 'list_names'}
