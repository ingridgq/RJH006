# %%
import json
import time
from deep_translator import GoogleTranslator

# Caminhos
input_path = r"C:\Users\ingri\Documents\IMIM\experiments\RJH006_subj_obj\RJH006_subj_obj_transcription.json"
output_path = r"C:\Users\ingri\Documents\IMIM\experiments\RJH006_subj_obj\transcription_test_english.json"

# Tradutor: de chinês para inglês
translator = GoogleTranslator(source='zh-TW', target='en')

# Carrega o JSON original
with open(input_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Traduz apenas os primeiros 2 segmentos (ajuste aqui se quiser)
subset = data["segments"][:10]

for i, segment in enumerate(subset):
    try:
        segment["text_eng"] = translator.translate(segment["text"])
        print(f"✅ Segmento {i+1}: {segment['text']} -> {segment['text_eng']}")
        
        for word in segment["words"]:
            word["text_eng"] = translator.translate(word["text"])
            time.sleep(0.2)
    except Exception as e:
        print(f"⚠️ Erro ao traduzir segmento {i+1}: {e}")
    time.sleep(1)

# Cria um novo JSON com apenas os segmentos traduzidos
output_data = {"segments": subset}

# Salva o resultado
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(output_data, f, ensure_ascii=False, indent=2)

print(f"\n✅ Tradução de teste concluída. Arquivo salvo em:\n{output_path}")
# Out:
# ✅ Segmento 1: 开始了。首先我是不会说名字啊！ -> here we go. First of all, I can’t say the name!
# ✅ Segmento 2: 嗯。 -> Um.
# ✅ Segmento 3: 朱茵、焦恩俊、周星驰、金映娟、张怡宁、七十。 -> Zhu Yin, Jiao Enjun, Stephen Chow, Jin Yingjuan, Zhang Yining, Seventy.
# ✅ Segmento 4: 啊，六七六四六三，朱茵、焦恩俊、金映娟、周星驰、张怡宁。 -> Ah, six seven six four six three, Zhu Yin, Jiao Enjun, Jin Yingjuan, Stephen Chow, Zhang Yining.
# ✅ Segmento 5: 好，我们下一个计算。接下来是个句子，朱茵教周星驰跳舞，八十二。 -> Okay, let's do the next calculation. Next is a sentence, Zhu Yin taught Zhou Xingchi to dance, eighty-two.
# ✅ Segmento 6: 啊，七十九、七十六，再然后七十三，朱茵教周星驰跳舞。 -> Ah, seventy-nine, seventy-six, and then seventy-three, Zhu Yin taught Stephen Chow how to dance.
# ✅ Segmento 7: 好的，接下来金映娟告诉焦恩俊了一个可怕的秘密，八十二。 -> Okay, next Jin Yingjuan told Jiao Enjun a terrible secret, eighty-two.
# ✅ Segmento 8: 嗯，七九七六七三，金映娟告诉了焦恩俊一个可怕的秘密。 -> Well, 797673, Jin Yingjuan told Jiao Enjun a terrible secret.
# ✅ Segmento 9: 好，继续。张怡宁给朱茵泡茶，二十四。 -> OK, continue. Zhang Yining makes tea for Zhu Yin, twenty-four.
# ✅ Segmento 10: 啊，二一十八、十五，张怡宁给朱茵泡茶。 -> Ah, 218, 15, Zhang Yining made tea for Zhu Yin.
#
# ✅ Tradução de teste concluída. Arquivo salvo em:
# C:\Users\ingri\Documents\IMIM\experiments\RJH006_subj_obj\transcription_test_english.json
